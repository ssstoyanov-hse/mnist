# %% [markdown]
# ## MNIST

# %%
import keras
import numpy as np
import tensorflow as tf
from keras.layers import Flatten, Dense
from keras.models import Sequential

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 8s 1us/step

# %%
X_train_full.shape
# Out:
# (60000, 28, 28)

# %%
X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.

# %%
model = Sequential([
    Flatten(input_shape=[28, 28]),
    Dense(300, activation="relu"),
    Dense(100, activation="relu"),
    Dense(10, activation="softmax")
])

# %%
model = Sequential([
    Flatten(input_shape=[28, 28]),
    Dense(128, activation="relu"),
    Dense(64, activation="relu"),
    Dense(32, activation="relu"),
    Dense(10, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                330
# =================================================================
# Total params: 111,146
# Trainable params: 111,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer='adam',
              metrics=["accuracy"])

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=20)
checkpoint_cb = keras.callbacks.ModelCheckpoint("my_mnist_model.h5", save_best_only=True)

history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid),
                    callbacks=[early_stopping_cb, checkpoint_cb])
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2541 - accuracy: 0.9240 - val_loss: 0.1310 - val_accuracy: 0.9614
# Epoch 2/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.1084 - accuracy: 0.9667 - val_loss: 0.1043 - val_accuracy: 0.9678
# Epoch 3/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0779 - accuracy: 0.9758 - val_loss: 0.0885 - val_accuracy: 0.9738
# Epoch 4/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0590 - accuracy: 0.9811 - val_loss: 0.0837 - val_accuracy: 0.9772
# Epoch 5/100
#  - ETA: 0s - loss: 0.0438 - accuracy: 0.9858
# Epoch 6/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0408 - accuracy: 0.9869 - val_loss: 0.0885 - val_accuracy: 0.9758
# Epoch 7/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0326 - accuracy: 0.9893 - val_loss: 0.1122 - val_accuracy: 0.9730
# Epoch 8/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0279 - accuracy: 0.9914 - val_loss: 0.0941 - val_accuracy: 0.9784
# Epoch 9/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0264 - accuracy: 0.9912 - val_loss: 0.0912 - val_accuracy: 0.9792
# Epoch 10/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0219 - accuracy: 0.9926 - val_loss: 0.1046 - val_accuracy: 0.9762
# Epoch 11/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0212 - accuracy: 0.9927 - val_loss: 0.1086 - val_accuracy: 0.9784
# Epoch 12/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0196 - accuracy: 0.9937 - val_loss: 0.0958 - val_accuracy: 0.9814
# Epoch 13/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0179 - accuracy: 0.9940 - val_loss: 0.1101 - val_accuracy: 0.9774
# Epoch 14/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0153 - accuracy: 0.9951 - val_loss: 0.1014 - val_accuracy: 0.9804
# Epoch 15/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 0.1141 - val_accuracy: 0.9782
# Epoch 16/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0144 - accuracy: 0.9950 - val_loss: 0.0915 - val_accuracy: 0.9818
# Epoch 17/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.1196 - val_accuracy: 0.9800
# Epoch 18/100
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.1144 - val_accuracy: 0.9798
# Epoch 19/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.1177 - val_accuracy: 0.9812
# Epoch 20/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0136 - accuracy: 0.9959 - val_loss: 0.1552 - val_accuracy: 0.9744
# Epoch 21/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0117 - accuracy: 0.9965 - val_loss: 0.1139 - val_accuracy: 0.9802
# Epoch 22/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.1303 - val_accuracy: 0.9814
# Epoch 23/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 0.1367 - val_accuracy: 0.9788
# Epoch 24/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.1467 - val_accuracy: 0.9796
