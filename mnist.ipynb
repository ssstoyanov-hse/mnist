# %% [markdown]
# ## MNIST

# %%
import keras
import numpy as np
import tensorflow as tf
from keras.layers import Flatten, Dense
from keras.models import Sequential

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train_full.shape
# Out:
# (60000, 28, 28)

# %%
X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.

# %%
model = Sequential([
    Flatten(input_shape=[28, 28]),
    Dense(128, activation="relu"),
    Dense(32, activation="relu"),
    Dense(64, activation="relu"),
    Dense(10, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 107,370
# Trainable params: 107,370
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer='adam',
              metrics=["accuracy"])

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10)
checkpoint_cb = keras.callbacks.ModelCheckpoint("model.h5", save_best_only=False)

history = model.fit(X_train, y_train, epochs=16,
                    validation_data=(X_valid, y_valid),
                    callbacks=[checkpoint_cb])
# Out:
# Epoch 1/16
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2673 - accuracy: 0.9202 - val_loss: 0.1334 - val_accuracy: 0.9602
# Epoch 2/16
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.1166 - accuracy: 0.9649 - val_loss: 0.0930 - val_accuracy: 0.9702
# Epoch 3/16
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0824 - accuracy: 0.9743 - val_loss: 0.0796 - val_accuracy: 0.9754
# Epoch 4/16
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0625 - accuracy: 0.9804 - val_loss: 0.0868 - val_accuracy: 0.9732
# Epoch 5/16
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.0507 - accuracy: 0.9837 - val_loss: 0.0877 - val_accuracy: 0.9748
# Epoch 6/16
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0418 - accuracy: 0.9861 - val_loss: 0.0893 - val_accuracy: 0.9760
# Epoch 7/16
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.0354 - accuracy: 0.9886 - val_loss: 0.0851 - val_accuracy: 0.9790
# Epoch 8/16
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0296 - accuracy: 0.9906 - val_loss: 0.1082 - val_accuracy: 0.9740
# Epoch 9/16
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0271 - accuracy: 0.9909 - val_loss: 0.0836 - val_accuracy: 0.9810
# Epoch 10/16
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0252 - accuracy: 0.9919 - val_loss: 0.0874 - val_accuracy: 0.9788
# Epoch 11/16
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0208 - accuracy: 0.9931 - val_loss: 0.0956 - val_accuracy: 0.9786
# Epoch 12/16
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0200 - accuracy: 0.9934 - val_loss: 0.1194 - val_accuracy: 0.9756
# Epoch 13/16
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0183 - accuracy: 0.9941 - val_loss: 0.1001 - val_accuracy: 0.9786
# Epoch 14/16
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0174 - accuracy: 0.9940 - val_loss: 0.1104 - val_accuracy: 0.9780
# Epoch 15/16
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.1115 - val_accuracy: 0.9786
# Epoch 16/16
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0158 - accuracy: 0.9949 - val_loss: 0.1369 - val_accuracy: 0.9742
